# %% [markdown]
# <a href="https://colab.research.google.com/github/Niacriza/TalentoTech/blob/main/Copia_de_factura.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Create a dataset: products to make cupcakes
# Let´s build the values lists
value_n_list = ['Cocoa', 'Harina', 'Fresas', 'Queso crema', 'Chispas de chocolate', 'Café', 'Mantequilla', 'Huevos', 'Azúcar', 'Leche']
#print(value_n_list)

value_c_list = [1, 2, 12, 1, 1, 1, 2, 5, 1, 1] # quantity in pounds. Strawberries and eggs in units. Milk in liters
value_p_list = [17850, 1990, 250, 9790, 10900, 20000, 14700, 500, 2350, 6000] # price in colombian pesos
value_r_list = list(map (lambda x, y: x*y, value_c_list,value_p_list))

#print(value_r_list)

# Let´s use a dictionary ({key:value})
# with the format {"str":list}
data_dict = {"Producto":value_n_list,
             "Precio":value_p_list,
             "Cantidad":value_c_list}#,
              #"Total":value_r_list}

#print(data_dict)

# Turn a dictionary into a dataframe
df = pd.DataFrame(data_dict)

print(df)

#total_pagar= sum(value_r_list)
print('')
#print('El total a pagar es: ', total_pagar)
# Call a variable

df['Subtotal'] = df['Precio'] * (df['Cantidad'])

df
# Out:
#                Producto  Precio  Cantidad
# 0                 Cocoa   17850         1
# 1                Harina    1990         2
# 2                Fresas     250        12
# 3           Queso crema    9790         1
# 4  Chispas de chocolate   10900         1
# 5                  Café   20000         1
# 6           Mantequilla   14700         2
# 7                Huevos     500         5
# 8                Azúcar    2350         1
# 9                 Leche    6000         1
#                Producto  Precio  Cantidad  Subtotal
# 0                 Cocoa   17850         1     17850
# 1                Harina    1990         2      3980
# 2                Fresas     250        12      3000
# 3           Queso crema    9790         1      9790
# 4  Chispas de chocolate   10900         1     10900
# 5                  Café   20000         1     20000
# 6           Mantequilla   14700         2     29400
# 7                Huevos     500         5      2500
# ...
